# %%
#G THANMAI
#BL.EN.U4CSE21054
#REGRESSION

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('embeddingsdata.xlsx')
df
# Out:
#       embed_0   embed_1   embed_2   embed_3   embed_4   embed_5   embed_6  \
# 0    0.009625 -0.029216  0.027109  0.023631 -0.004972  0.031757 -0.045125
# 1   -0.007535 -0.039844  0.030167  0.031224  0.004742  0.028289 -0.068723
# 2    0.022408 -0.030840  0.032328  0.046965  0.007798  0.025860 -0.065093
# 3    0.019677 -0.034055  0.012662  0.070387 -0.011170  0.017842 -0.050945
# 4    0.017678 -0.030323  0.012829  0.065267 -0.025161  0.011964 -0.050590
# ..        ...       ...       ...       ...       ...       ...       ...
# 895  0.019743 -0.071799  0.022546  0.049042 -0.005767 -0.016275 -0.037731
# 896  0.000186 -0.027604  0.010623  0.038237 -0.026675  0.020215 -0.040816
# 897  0.018066 -0.032152  0.039794  0.047608  0.003898  0.024092 -0.056508
# 898 -0.003492 -0.022739  0.021777  0.044054 -0.005621  0.013863 -0.079196
# 899  0.013689 -0.037855  0.039763  0.035750  0.004115  0.005637 -0.050556
#
#       embed_7   embed_8   embed_9  ...  embed_759  embed_760  embed_761  \
# ...

# %%
#Scatter plot
import seaborn as sns
sns.scatterplot(data = df,x='embed_8',y='embed_3')
# Out:
# <AxesSubplot:xlabel='embed_8', ylabel='embed_3'>

# %%
sns.scatterplot(data = df,x='embed_7',y='Label')
# Out:
# <AxesSubplot:xlabel='embed_7', ylabel='Label'>

# %%
cols = ['embed_1','embed_2','embed_3','embed_4','embed_5','embed_6','embed_7','embed_8','embed_9','embed_10','Label']

# %%
sub_df = df[cols]

# %%
correl_matrix = sub_df.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
Target = sub_df["Label"]
correl_matrix = sub_df.corr()
mask = np.zeros_like(correl_matrix)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(20, 20))
    cmap =sns.cubehelix_palette(as_cmap=True)
    ax = sns.heatmap(correl_matrix,mask=mask,square=True,linewidths=2.5,cmap=cmap,annot=True)

# %%
inp = df[['embed_7']]
out = df['Label']
x_train,x_test,y_train,y_test = train_test_split(inp,out,test_size=0.33, random_state=42)

# %%
#Linear Regression
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
model_linreg = linear_model.LinearRegression()
model_linreg.fit(x_train,y_train)
y_pred = model_linreg.predict(x_test)
print("Mean squared error: %.2f" % mean_squared_error(y_test,y_pred))
# Out:
# Mean squared error: 6.92

# %%
x = df[(df['Label'] == 0) | (df['Label'] == 1)].iloc[:, 0:768]
y = df[(df['Label'] == 0) | (df['Label'] == 1)].iloc[:, 768]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33, random_state=42)

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
model_logreg = LogisticRegression(random_state = 0)
model_logreg.fit(x_train,y_train)
y_pred = model_logreg.predict(x_test)

accuracy = accuracy_score(y_test,y_pred)
print(f"Accuracy of Logistic Regression model is: {accuracy} ")
# Out:
# Accuracy of Logistic Regression model is: 0.8159203980099502

# %%
inp = df[['embed_10']]
out = df['embed_154']
x_train,x_test,y_train,y_test = train_test_split(inp,out,test_size=0.33, random_state=42)

# %%
#Regression Tree
from sklearn.tree import DecisionTreeRegressor
model_regrtree = DecisionTreeRegressor(max_depth = 5)
model_regrtree.fit(x_train,y_train)
y_pred = model_regrtree.predict(x_test)

print(f"Mean squared error:  {mean_squared_error(y_test,y_pred)}")
# Out:
# Mean squared error:  0.00017374019474252162

# %%
max_depths = np.arange(1, 11)

# Initialize an empty list to store MSE values
mse_values = []

# Iterate through different max_depth values and calculate MSE for each
for depth in max_depths:
    model = DecisionTreeRegressor(max_depth=depth)
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_values.append(mse)

# Create a plot to visualize MSE vs. max_depth
plt.figure(figsize=(10, 6))
plt.plot(max_depths, mse_values, marker='o', linestyle='-')
plt.title('MSE vs. max_depth for Decision Tree Regressor')
plt.xlabel('max_depth')
plt.ylabel('Mean Squared Error (MSE)')
plt.grid()
plt.show()

# %%
#KNN Regressor
from sklearn.neighbors import KNeighborsRegressor
model_knn = KNeighborsRegressor(n_neighbors = 5)
model_knn.fit(x_train,y_train)
y_pred = model_knn.predict(x_test)

print(f"Mean squared error:  {mean_squared_error(y_test,y_pred)}")
# Out:
# Mean squared error:  0.00018323465406027803

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

# Create a range of n_neighbors values to test
n_neighbors_values = np.arange(1, 16)

# Initialize an empty list to store MSE values
mse_values = []

# Iterate through different n_neighbors values and calculate MSE for each
for n_neighbors in n_neighbors_values:
    model = KNeighborsRegressor(n_neighbors=n_neighbors)
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_values.append(mse)

# Create a plot to visualize MSE vs. n_neighbors
plt.figure(figsize=(10, 6))
plt.plot(n_neighbors_values, mse_values, marker='o', linestyle='-')
plt.title('MSE vs. n_neighbors for K-Nearest Neighbors Regressor')
plt.xlabel('n_neighbors')
plt.ylabel('Mean Squared Error (MSE)')
plt.grid()
plt.show()
